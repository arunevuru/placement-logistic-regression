# %% [markdown]
# <a href="https://colab.research.google.com/github/arunevuru/placement-logistic-regression/blob/main/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
#steps
#0.Preprocess+EDA+Feature Selection
#1.Extract Input nd Output cols
#2.Scale The Values
#3.Train Test Split
#4.Train The Model
#5.Evaluate Model/Model Selection
#6.Deploy The Model
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 40   4.9  134.0
# 18   4.0  100.0
# 16   5.2  224.0
# 24   4.7  121.0
# 12   5.4  139.0
# ..   ...    ...
# 64   7.0   64.0
# 29   7.0  112.0
# 4    5.8  142.0
# 66   6.9   96.0
# 7    5.0   63.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 40    0
# 18    0
# 16    0
# 24    0
# 12    0
#      ..
# 64    1
# 29    1
# 4     0
# 66    1
# 7     0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 19   5.2  132.0
# 68   4.0   75.0
# 15   5.1  176.0
# 84   5.7  169.0
# 27   6.0  124.0
# 0    6.8  123.0
# 60   6.9  139.0
# 2    5.3  121.0
# 28   5.2   90.0
# 36   5.7  140.0

# %%
y_test
# Out:
# 19    0
# 68    0
# 15    0
# 84    0
# 27    1
# 0     1
# 60    1
# 2     0
# 28    0
# 36    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
x_train=scalar.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.97867582,  0.27058058],
#        [-1.75433865, -0.56491546],
#        [-0.72012154,  2.48218775],
#        [-1.15104534, -0.04887379],
#        [-0.54775202,  0.39344765],
#        [ 1.0897584 , -1.79358611],
#        [ 0.48646508,  0.36887423],
#        [ 0.40028032, -2.11304048],
#        [-0.97867582,  0.78662225],
#        [ 0.74501936,  0.36887423],
#        [ 0.05554129, -1.42498491],
#        [ 0.6588346 ,  0.44259447],
#        [ 0.22791081,  0.1231401 ],
#        [-0.20301299,  1.0569298 ],
#        [-0.11682823, -0.41747498],
#        [ 1.34831267, -0.835223  ],
#        [-1.40959961,  0.63918177],
#        [-2.18526244,  2.70334846],
#        [ 1.69305171, -1.08095713],
#        [-0.03064347,  0.63918177],
#        [-0.54775202,  0.29515399],
#        [ 0.40028032,  0.90948932],
#        [ 1.95160598,  1.10607662],
#        [ 1.26212791,  0.86034249],
#        [-0.54775202, -0.22088768],
#        [ 0.40028032,  0.17228693],
#        [-1.06486058, -0.2700345 ],
# ...

# %%
x_test=scalar.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.48265996,  0.10570359],
#        [-1.96776753, -1.83787858],
#        [-0.60641892,  1.60601264],
#        [ 0.13613486,  1.36732711],
#        [ 0.50741175, -0.16707987],
#        [ 1.49748347, -0.2011778 ],
#        [ 1.62124243,  0.34438912],
#        [-0.358901  , -0.26937367],
#        [-0.48265996, -1.32640959],
#        [ 0.13613486,  0.37848705]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 19    0
# 68    0
# 15    0
# 84    0
# 27    1
# 0     1
# 60    1
# 2     0
# 28    0
# 36    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
